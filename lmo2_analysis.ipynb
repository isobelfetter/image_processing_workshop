# %%
from PIL import Image
import tifffile
import matplotlib.pyplot as plt
from matplotlib import colors
import pandas as pd
import numpy as np
import scipy.ndimage as ndi
import imageio.v2 as imageio

# %%
lmo2_img = imageio.imread('Lmo2_PyMT.tif')

# %%
plt.imshow(lmo2_img)

# %%
plt.imshow(lmo2_img[:,:,1]>100)

# %%
cell_labels, cell_number = ndi.label(lmo2_img[:,:,1]>100)
cell_number
# Out:
# 43

# %%
plt.imshow(cell_labels,cmap='gray')
plt.colorbar()
plt.show()
